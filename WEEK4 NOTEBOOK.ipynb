# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# # Finding the best location for an office in NEW YORK

# %% [markdown]
# The project focuses on finding a perfect neighbourhood for an office in New York. I chose The Subway as a central point. The radius chosen was 500 meters.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          92 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.21.0-py_0
#
#
#
# Downloading and Extracting Packages
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36h8c4c3a4_1000         346 KB  conda-forge
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-2.8           |   py36h45558ae_2         628 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     pandas-1.0.3               |   py36h830a2c2_1        11.1 MB  conda-forge
#     pysocks-1.7.1              |   py36h9f0ad1d_1          27 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     urllib3-1.25.9             |             py_0          92 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-19.3.0-py_0
#   branca             conda-forge/noarch::branca-0.4.0-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36h8c4c3a4_1000
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9f0ad1d_1006
#   cryptography       conda-forge/linux-64::cryptography-2.8-py36h45558ae_2
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1001
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.9-py_1
#   importlib-metadata conda-forge/linux-64::importlib-metadata-1.6.0-py36h9f0ad1d_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.6.0-0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.2.0-py36h9f0ad1d_1
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h8c4c3a4_1
#   pandas             conda-forge/linux-64::pandas-1.0.3-py36h830a2c2_1
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9f0ad1d_1
#   pytz               conda-forge/noarch::pytz-2019.3-py_0
#   requests           conda-forge/noarch::requests-2.23.0-pyh8c360ce_2
#   toolz              conda-forge/noarch::toolz-0.10.0-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.9-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#   zipp               conda-forge/noarch::zipp-3.1.0-py_0
#
#
#
# Downloading and Extracting Packages
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# cryptography-2.8     | 628 KB    | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# chardet-3.0.4        | 188 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# urllib3-1.25.9       | 92 KB     | ##################################### | 100%
# brotlipy-0.7.0       | 346 KB    | ##################################### | 100%
# pandas-1.0.3         | 11.1 MB   | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'XW0IGSY5NENK2FK0YRS0HV3RSULEFHPEWBPUMMYVL3U4Y0RQ' # your Foursquare ID
CLIENT_SECRET = 'V2XH10X5Q55G3WWZ4XAXVDMNZJZIXFRYFLYVGERKEUX5OEYD' # your Foursquare Secret
VERSION = '20180604' # Foursquare API version
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: XW0IGSY5NENK2FK0YRS0HV3RSULEFHPEWBPUMMYVL3U4Y0RQ
# CLIENT_SECRET:V2XH10X5Q55G3WWZ4XAXVDMNZJZIXFRYFLYVGERKEUX5OEYD

# %% [markdown]
# ## LOCATION OF CENTRAL AREA

# %%
# GPS coordinates of Fulton Street (New York City Subway), United States. Latitude: 40.7061 Longitude: -74.0046.
latitude = 40.7061
longitude = -74.0046
radius = 500 #500 meters

# %% [markdown]
# #### Define the corresponding URL

# %%
search_query = 'Office'
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=XW0IGSY5NENK2FK0YRS0HV3RSULEFHPEWBPUMMYVL3U4Y0RQ&client_secret=V2XH10X5Q55G3WWZ4XAXVDMNZJZIXFRYFLYVGERKEUX5OEYD&ll=40.7061,-74.0046&v=20180604&query=Office&radius=500&limit=30'

# %% [markdown]
# #### get results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e9ce9e6fb34b5001bd90e5e'},
#  'response': {'venues': [{'id': '4fd244dce4b03e7cee3dd4b1',
#     'name': 'US Post Office',
#     'location': {'address': '114 John St',
#      'crossStreet': 'btwn Pearl & Gold St',
#      'lat': 40.707567,
#      'lng': -74.005874,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707567,
#        'lng': -74.005874},
#       {'label': 'entrance', 'lat': 40.707596, 'lng': -74.005785}],
#      'distance': 195,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['114 John St (btwn Pearl & Gold St)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4ec52dcb9911232436efc8d0',
#     'name': 'CPU Innovation Development Office',
#     'location': {'address': '199 Water St',
#      'crossStreet': 'John St',
#      'lat': 40.707121742186054,
#      'lng': -74.0042394688219,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707121742186054,
#        'lng': -74.0042394688219}],
#      'distance': 117,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['199 Water St (John St)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '5c816dae98fbfc002bfc5e33',
#     'name': 'Moinian Group Field Office',
#     'location': {'lat': 40.70752,
#      'lng': -74.006381,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70752,
#        'lng': -74.006381}],
#      'distance': 218,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10038', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4b44ae92f964a52058f925e3',
#     'name': 'US Post Office',
#     'location': {'address': '1 Hanover St',
#      'crossStreet': 'at Exchange Pl.',
#      'lat': 40.70540636870765,
#      'lng': -74.00893076718427,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70540636870765,
#        'lng': -74.00893076718427}],
#      'distance': 373,
#      'postalCode': '10005',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 Hanover St (at Exchange Pl.)',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4b903af5f964a520b77d33e3',
#     'name': 'FedEx Office Print & Ship Center',
#     'location': {'address': '110 William St',
#      'lat': 40.7090542,
#      'lng': -74.0068384,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7090542,
#        'lng': -74.0068384}],
#      'distance': 379,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['110 William St',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b1f',
#       'name': 'Shipping Store',
#       'pluralName': 'Shipping Stores',
#       'shortName': 'Shipping Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4f6af313e4b00b83012a586a',
#     'name': 'US Post Office Collection Box',
#     'location': {'address': '64 Gold St.',
#      'crossStreet': 'at Ann St.',
#      'lat': 40.70886487781536,
#      'lng': -74.00542974472046,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70886487781536,
#        'lng': -74.00542974472046}],
#      'distance': 315,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['64 Gold St. (at Ann St.)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '533b449c11d2b4ba93d9a9f8',
#     'name': 'The Appellate Law Office Of Stephen Preziosi',
#     'location': {'address': '48 Wall Street, 5th Floor',
#      'crossStreet': '41st',
#      'lat': 40.7064168,
#      'lng': -74.0090871,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7064168,
#        'lng': -74.0090871}],
#      'distance': 380,
#      'postalCode': '10005',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['48 Wall Street, 5th Floor (41st)',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3f',
#       'name': 'Lawyer',
#       'pluralName': 'Lawyers',
#       'shortName': 'Lawyer',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lawschool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '82805419'},
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '55135e3c498e89c3a6a6f6e4',
#     'name': 'The Law Office of McCarthy A. Hawkins',
#     'location': {'address': '30 Wall St Fl 8',
#      'lat': 40.7071651,
#      'lng': -74.0100875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7071651,
#        'lng': -74.0100875}],
#      'distance': 478,
#      'postalCode': '10005',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['30 Wall St Fl 8',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3f',
#       'name': 'Lawyer',
#       'pluralName': 'Lawyers',
#       'shortName': 'Lawyer',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lawschool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '130406397'},
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '578ea005cd10fe35f4ae1e65',
#     'name': 'Pace University Office of Residential Life and Housing',
#     'location': {'address': '1 Pace Plz',
#      'lat': 40.710781,
#      'lng': -74.004342,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.710781,
#        'lng': -74.004342}],
#      'distance': 521,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 Pace Plz',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d197941735',
#       'name': 'College Administrative Building',
#       'pluralName': 'College Administrative Buildings',
#       'shortName': 'Administrative Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/administrativebuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '523c633f11d207b8ce13121c',
#     'name': 'The Office of Katmando',
#     'location': {'address': '88 Pine St',
#      'crossStreet': 'Water',
#      'lat': 40.705343,
#      'lng': -74.005675,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.705343,
#        'lng': -74.005675}],
#      'distance': 123,
#      'postalCode': '10005',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['88 Pine St (Water)',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '523696fd11d2807c81e7eb89',
#     'name': 'Office Best Denki',
#     'location': {'address': 'Jl.Asia Afrika Lot 19 lt 4',
#      'crossStreet': 'Senayan City',
#      'lat': 40.7051078,
#      'lng': -74.0056827,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7051078,
#        'lng': -74.0056827}],
#      'distance': 143,
#      'postalCode': '10270',
#      'cc': 'US',
#      'city': 'Jakarta Pusat',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Jl.Asia Afrika Lot 19 lt 4 (Senayan City)',
#       'Jakarta Pusat, NY 10270',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d122951735',
#       'name': 'Electronics Store',
#       'pluralName': 'Electronics Stores',
#       'shortName': 'Electronics',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4e6509cfb0fb188e8ecdbb6e',
#     'name': 'Apollo Docs Office',
#     'location': {'address': '120 Wall St, Fl 18',
#      'lat': 40.705456,
#      'lng': -74.005026,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.705456,
#        'lng': -74.005026}],
#      'distance': 80,
#      'postalCode': '10005',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['120 Wall St, Fl 18',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d125941735',
#       'name': 'Tech Startup',
#       'pluralName': 'Tech Startups',
#       'shortName': 'Tech Startup',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '59d3bf6fca18ea1b0ddd8572',
#     'name': 'True Office Learning',
#     'location': {'address': '180 Maiden Ln',
#      'lat': 40.705358373548925,
#      'lng': -74.0055323386184,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.705358373548925,
#        'lng': -74.0055323386184}],
#      'distance': 114,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['180 Maiden Ln',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '53da7bcd498e9839fb43320e',
#     'name': 'law office of marshall dennehey',
#     'location': {'lat': 40.706158471941386,
#      'lng': -74.0057199987696,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.706158471941386,
#        'lng': -74.0057199987696}],
#      'distance': 94,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3f',
#       'name': 'Lawyer',
#       'pluralName': 'Lawyers',
#       'shortName': 'Lawyer',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lawschool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4ba135c2f964a52066a237e3',
#     'name': 'Bowne & Co. Printing Office',
#     'location': {'address': '207-209 Water St',
#      'crossStreet': 'btwn Fulton & Beekman St',
#      'lat': 40.707362323027475,
#      'lng': -74.00350391864777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707362323027475,
#        'lng': -74.00350391864777}],
#      'distance': 168,
#      'postalCode': '10038',
#      'cc': 'US',
#      'neighborhood': 'Financial District',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['207-209 Water St (btwn Fulton & Beekman St)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d121951735',
#       'name': 'Paper / Office Supplies Store',
#       'pluralName': 'Paper / Office Supplies Stores',
#       'shortName': 'Office Supplies',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/papergoods_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4f32540719836c91c7ccec82',
#     'name': 'Ark Corporate Office',
#     'location': {'address': '19 Fulton St',
#      'lat': 40.706946,
#      'lng': -74.003707,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.706946,
#        'lng': -74.003707}],
#      'distance': 120,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['19 Fulton St',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4df4470988772e1f81570064',
#     'name': '9fold Main Office',
#     'location': {'lat': 40.707207,
#      'lng': -74.004751,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707207,
#        'lng': -74.004751}],
#      'distance': 123,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4bf1acbb3fa220a188931820',
#     'name': 'NH Media downtown office',
#     'location': {'address': '200 Water St',
#      'crossStreet': 'Fulton',
#      'lat': 40.70727924713176,
#      'lng': -74.00446327059542,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70727924713176,
#        'lng': -74.00446327059542}],
#      'distance': 131,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['200 Water St (Fulton)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '50b68fd9e4b0cb5f35f7bc6d',
#     'name': 'The Office',
#     'location': {'address': '80 Maiden Ln',
#      'lat': 40.707084,
#      'lng': -74.007795,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707084,
#        'lng': -74.007795}],
#      'distance': 291,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['80 Maiden Ln',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '509b6744e4b00d566f350992',
#     'name': 'FedEx Office Print & Ship Center',
#     'location': {'address': '100 Wall St',
#      'lat': 40.705368,
#      'lng': -74.006832,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.705368,
#        'lng': -74.006832}],
#      'distance': 205,
#      'postalCode': '10005',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['100 Wall St',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b1f',
#       'name': 'Shipping Store',
#       'pluralName': 'Shipping Stores',
#       'shortName': 'Shipping Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4d389697f8e0a093af737e67',
#     'name': 'Todd Burkes Office',
#     'location': {'lat': 40.70736,
#      'lng': -74.004063,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70736,
#        'lng': -74.004063}],
#      'distance': 147,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4df659c762e1288ed30d4d8d',
#     'name': "Matt's Office @717",
#     'location': {'lat': 40.707528,
#      'lng': -74.004711,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707528,
#        'lng': -74.004711}],
#      'distance': 159,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '5d1a186d7ad194002347f53d',
#     'name': 'USPS Post Office - John St',
#     'location': {'lat': 40.707431,
#      'lng': -74.005693,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707431,
#        'lng': -74.005693}],
#      'distance': 174,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10038', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '53df9b84498e6c335b4161a2',
#     'name': 'Office of the State Comptroller',
#     'location': {'address': '59 Maiden Ln',
#      'crossStreet': 'William st',
#      'lat': 40.70864697996661,
#      'lng': -74.00829246953786,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70864697996661,
#        'lng': -74.00829246953786},
#       {'label': 'entrance', 'lat': 40.708581, 'lng': -74.008162}],
#      'distance': 421,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['59 Maiden Ln (William st)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'shortName': 'Government',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '50dcbad78055ba17b3d55c8c',
#     'name': 'Executive Office',
#     'location': {'address': '120 Wall St',
#      'lat': 40.70483901199343,
#      'lng': -74.00624513626099,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70483901199343,
#        'lng': -74.00624513626099}],
#      'distance': 197,
#      'postalCode': '10005',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['120 Wall St',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '50328a8e91d4c4b30a586d6c',
#       'name': 'Non-Profit',
#       'pluralName': 'Non-Profits',
#       'shortName': 'Non-Profit',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '54342fce498ec8da8a6f3e40',
#     'name': 'The Law Office Of Frank Taddeo Jr.',
#     'location': {'address': '100 Wall St Fl 23',
#      'lat': 40.705238,
#      'lng': -74.006729,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.705238,
#        'lng': -74.006729}],
#      'distance': 203,
#      'postalCode': '10005',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['100 Wall St Fl 23',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3f',
#       'name': 'Lawyer',
#       'pluralName': 'Lawyers',
#       'shortName': 'Lawyer',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lawschool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4fedf000e4b0ac0d2ea86933',
#     'name': "Dr. Levey's Office",
#     'location': {'lat': 40.70656283795328,
#      'lng': -74.00707427194442,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70656283795328,
#        'lng': -74.00707427194442}],
#      'distance': 215,
#      'postalCode': '10005',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10005', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4bdeec8fffdec928491aeaa1',
#     'name': 'CenterLink: The Community Of LGBT Centers - Main Office',
#     'location': {'address': '120 Wall St',
#      'lat': 40.704683,
#      'lng': -74.006634,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.704683,
#        'lng': -74.006634}],
#      'distance': 233,
#      'postalCode': '10005',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['120 Wall St',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4c2bb11ef7acef3b4f5ced0c',
#     'name': 'ict4me usa - new york office',
#     'location': {'address': '110 Wall Street 11FL',
#      'crossStreet': 'Front St',
#      'lat': 40.70455434560177,
#      'lng': -74.00649189949036,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70455434560177,
#        'lng': -74.00649189949036}],
#      'distance': 234,
#      'postalCode': '10005',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['110 Wall Street 11FL (Front St)',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False},
#    {'id': '4c72ad73d944224b2d4f0d29',
#     'name': 'Steve & Dmitriys Office',
#     'location': {'address': '100 wall 26th',
#      'lat': 40.705455,
#      'lng': -74.007291,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.705455,
#        'lng': -74.007291}],
#      'distance': 238,
#      'postalCode': '10005',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['100 wall 26th',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587341927',
#     'hasPerk': False}]}}

# %% [markdown]
# ## pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                               name  \
# 0  4fd244dce4b03e7cee3dd4b1                     US Post Office
# 1  4ec52dcb9911232436efc8d0  CPU Innovation Development Office
# 2  5c816dae98fbfc002bfc5e33         Moinian Group Field Office
# 3  4b44ae92f964a52058f925e3                     US Post Office
# 4  4b903af5f964a520b77d33e3   FedEx Office Print & Ship Center
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d172941735', 'name': 'P...  v-1587341927    False
# 1  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1587341927    False
# 2  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1587341927    False
# 3  [{'id': '4bf58dd8d48988d172941735', 'name': 'P...  v-1587341927    False
# 4  [{'id': '52f2ab2ebcbc57f1066b8b1f', 'name': 'S...  v-1587341927    False
#
#   location.address  location.crossStreet  location.lat  location.lng  \
# 0      114 John St  btwn Pearl & Gold St     40.707567    -74.005874
# 1     199 Water St               John St     40.707122    -74.004239
# 2              NaN                   NaN     40.707520    -74.006381
# 3     1 Hanover St       at Exchange Pl.     40.705406    -74.008931
# 4   110 William St                   NaN     40.709054    -74.006838
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.707567, 'lng':...                195
# 1  [{'label': 'display', 'lat': 40.70712174218605...                117
# 2  [{'label': 'display', 'lat': 40.70752, 'lng': ...                218
# 3  [{'label': 'display', 'lat': 40.70540636870765...                373
# 4  [{'label': 'display', 'lat': 40.7090542, 'lng'...                379
#
#   location.postalCode location.cc location.city location.state  \
# 0               10038          US      New York             NY
# 1               10038          US      New York             NY
# 2               10038          US      New York             NY
# 3               10005          US      New York             NY
# 4               10038          US      New York             NY
#
#   location.country                          location.formattedAddress  \
# 0    United States  [114 John St (btwn Pearl & Gold St), New York,...
# 1    United States  [199 Water St (John St), New York, NY 10038, U...
# 2    United States                [New York, NY 10038, United States]
# 3    United States  [1 Hanover St (at Exchange Pl.), New York, NY ...
# 4    United States  [110 William St, New York, NY 10038, United St...
#
#   venuePage.id location.neighborhood
# 0          NaN                   NaN
# 1          NaN                   NaN
# 2          NaN                   NaN
# 3          NaN                   NaN
# 4          NaN                   NaN

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                                      US Post Office
# 1                   CPU Innovation Development Office
# 2                          Moinian Group Field Office
# 3                                      US Post Office
# 4                    FedEx Office Print & Ship Center
# 5                       US Post Office Collection Box
# 6        The Appellate Law Office Of Stephen Preziosi
# 7               The Law Office of McCarthy A. Hawkins
# 8   Pace University Office of Residential Life and...
# 9                              The Office of Katmando
# 10                                  Office Best Denki
# 11                                 Apollo Docs Office
# 12                               True Office Learning
# 13                    law office of marshall dennehey
# 14                        Bowne & Co. Printing Office
# 15                               Ark Corporate Office
# 16                                  9fold Main Office
# 17                           NH Media downtown office
# 18                                         The Office
# 19                   FedEx Office Print & Ship Center
# 20                                 Todd Burkes Office
# 21                                 Matt's Office @717
# 22                         USPS Post Office - John St
# 23                    Office of the State Comptroller
# 24                                   Executive Office
# 25                 The Law Office Of Frank Taddeo Jr.
# 26                                 Dr. Levey's Office
# 27  CenterLink: The Community Of LGBT Centers - Ma...
# 28                       ict4me usa - new york office
# 29                            Steve & Dmitriys Office
#
#                          categories                     address  \
# 0                       Post Office                 114 John St
# 1                            Office                199 Water St
# 2                            Office                         NaN
# 3                       Post Office                1 Hanover St
# 4                    Shipping Store              110 William St
# 5                       Post Office                 64 Gold St.
# 6                            Lawyer   48 Wall Street, 5th Floor
# 7                            Lawyer             30 Wall St Fl 8
# 8   College Administrative Building                  1 Pace Plz
# 9                            Office                  88 Pine St
# 10                Electronics Store  Jl.Asia Afrika Lot 19 lt 4
# 11                     Tech Startup          120 Wall St, Fl 18
# 12                           Office               180 Maiden Ln
# 13                           Lawyer                         NaN
# 14    Paper / Office Supplies Store            207-209 Water St
# 15                           Office                19 Fulton St
# 16                           Office                         NaN
# 17                           Office                200 Water St
# 18                           Office                80 Maiden Ln
# 19                   Shipping Store                 100 Wall St
# 20                           Office                         NaN
# 21                             None                         NaN
# 22                      Post Office                         NaN
# 23              Government Building                59 Maiden Ln
# 24                       Non-Profit                 120 Wall St
# 25                           Lawyer           100 Wall St Fl 23
# 26                  Doctor's Office                         NaN
# 27                           Office                 120 Wall St
# 28                           Office        110 Wall Street 11FL
# 29                  Coworking Space               100 wall 26th
#
#                  crossStreet        lat        lng  \
# 0       btwn Pearl & Gold St  40.707567 -74.005874
# 1                    John St  40.707122 -74.004239
# 2                        NaN  40.707520 -74.006381
# 3            at Exchange Pl.  40.705406 -74.008931
# 4                        NaN  40.709054 -74.006838
# 5                 at Ann St.  40.708865 -74.005430
# 6                       41st  40.706417 -74.009087
# 7                        NaN  40.707165 -74.010087
# 8                        NaN  40.710781 -74.004342
# 9                      Water  40.705343 -74.005675
# 10              Senayan City  40.705108 -74.005683
# 11                       NaN  40.705456 -74.005026
# 12                       NaN  40.705358 -74.005532
# 13                       NaN  40.706158 -74.005720
# 14  btwn Fulton & Beekman St  40.707362 -74.003504
# 15                       NaN  40.706946 -74.003707
# 16                       NaN  40.707207 -74.004751
# 17                    Fulton  40.707279 -74.004463
# 18                       NaN  40.707084 -74.007795
# 19                       NaN  40.705368 -74.006832
# 20                       NaN  40.707360 -74.004063
# 21                       NaN  40.707528 -74.004711
# 22                       NaN  40.707431 -74.005693
# 23                William st  40.708647 -74.008292
# 24                       NaN  40.704839 -74.006245
# 25                       NaN  40.705238 -74.006729
# 26                       NaN  40.706563 -74.007074
# 27                       NaN  40.704683 -74.006634
# 28                  Front St  40.704554 -74.006492
# 29                       NaN  40.705455 -74.007291
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 40.707567, 'lng':...       195      10038
# 1   [{'label': 'display', 'lat': 40.70712174218605...       117      10038
# 2   [{'label': 'display', 'lat': 40.70752, 'lng': ...       218      10038
# 3   [{'label': 'display', 'lat': 40.70540636870765...       373      10005
# 4   [{'label': 'display', 'lat': 40.7090542, 'lng'...       379      10038
# 5   [{'label': 'display', 'lat': 40.70886487781536...       315      10038
# 6   [{'label': 'display', 'lat': 40.7064168, 'lng'...       380      10005
# 7   [{'label': 'display', 'lat': 40.7071651, 'lng'...       478      10005
# 8   [{'label': 'display', 'lat': 40.710781, 'lng':...       521      10038
# 9   [{'label': 'display', 'lat': 40.705343, 'lng':...       123      10005
# 10  [{'label': 'display', 'lat': 40.7051078, 'lng'...       143      10270
# 11  [{'label': 'display', 'lat': 40.705456, 'lng':...        80      10005
# 12  [{'label': 'display', 'lat': 40.70535837354892...       114      10038
# 13  [{'label': 'display', 'lat': 40.70615847194138...        94        NaN
# 14  [{'label': 'display', 'lat': 40.70736232302747...       168      10038
# 15  [{'label': 'display', 'lat': 40.706946, 'lng':...       120      10038
# 16  [{'label': 'display', 'lat': 40.707207, 'lng':...       123        NaN
# 17  [{'label': 'display', 'lat': 40.70727924713176...       131      10038
# 18  [{'label': 'display', 'lat': 40.707084, 'lng':...       291      10038
# 19  [{'label': 'display', 'lat': 40.705368, 'lng':...       205      10005
# 20  [{'label': 'display', 'lat': 40.70736, 'lng': ...       147        NaN
# 21  [{'label': 'display', 'lat': 40.707528, 'lng':...       159        NaN
# 22  [{'label': 'display', 'lat': 40.707431, 'lng':...       174      10038
# 23  [{'label': 'display', 'lat': 40.70864697996661...       421      10038
# 24  [{'label': 'display', 'lat': 40.70483901199343...       197      10005
# 25  [{'label': 'display', 'lat': 40.705238, 'lng':...       203      10005
# 26  [{'label': 'display', 'lat': 40.70656283795328...       215      10005
# 27  [{'label': 'display', 'lat': 40.704683, 'lng':...       233      10005
# 28  [{'label': 'display', 'lat': 40.70455434560177...       234      10005
# 29  [{'label': 'display', 'lat': 40.705455, 'lng':...       238      10005
#
#     cc           city state        country  \
# 0   US       New York    NY  United States
# 1   US       New York    NY  United States
# 2   US       New York    NY  United States
# 3   US       New York    NY  United States
# 4   US       New York    NY  United States
# 5   US       New York    NY  United States
# 6   US       New York    NY  United States
# 7   US       New York    NY  United States
# 8   US       New York    NY  United States
# 9   US       New York    NY  United States
# 10  US  Jakarta Pusat    NY  United States
# 11  US       New York    NY  United States
# 12  US       New York    NY  United States
# 13  US       New York    NY  United States
# 14  US       New York    NY  United States
# 15  US       New York    NY  United States
# 16  US       New York    NY  United States
# 17  US       New York    NY  United States
# 18  US       New York    NY  United States
# 19  US       New York    NY  United States
# 20  US       New York    NY  United States
# 21  US       New York    NY  United States
# 22  US       New York    NY  United States
# 23  US       New York    NY  United States
# 24  US       New York    NY  United States
# 25  US       New York    NY  United States
# 26  US       New York    NY  United States
# 27  US       New York    NY  United States
# 28  US       New York    NY  United States
# 29  US       New York    NY  United States
#
#                                      formattedAddress        neighborhood  \
# 0   [114 John St (btwn Pearl & Gold St), New York,...                 NaN
# 1   [199 Water St (John St), New York, NY 10038, U...                 NaN
# 2                 [New York, NY 10038, United States]                 NaN
# 3   [1 Hanover St (at Exchange Pl.), New York, NY ...                 NaN
# 4   [110 William St, New York, NY 10038, United St...                 NaN
# 5   [64 Gold St. (at Ann St.), New York, NY 10038,...                 NaN
# 6   [48 Wall Street, 5th Floor (41st), New York, N...                 NaN
# 7   [30 Wall St Fl 8, New York, NY 10005, United S...                 NaN
# 8     [1 Pace Plz, New York, NY 10038, United States]                 NaN
# 9   [88 Pine St (Water), New York, NY 10005, Unite...                 NaN
# 10  [Jl.Asia Afrika Lot 19 lt 4 (Senayan City), Ja...                 NaN
# 11  [120 Wall St, Fl 18, New York, NY 10005, Unite...                 NaN
# 12  [180 Maiden Ln, New York, NY 10038, United Sta...                 NaN
# 13                      [New York, NY, United States]                 NaN
# 14  [207-209 Water St (btwn Fulton & Beekman St), ...  Financial District
# 15  [19 Fulton St, New York, NY 10038, United States]                 NaN
# 16                      [New York, NY, United States]                 NaN
# 17  [200 Water St (Fulton), New York, NY 10038, Un...                 NaN
# 18  [80 Maiden Ln, New York, NY 10038, United States]                 NaN
# 19   [100 Wall St, New York, NY 10005, United States]                 NaN
# 20                      [New York, NY, United States]                 NaN
# 21                      [New York, NY, United States]                 NaN
# 22                [New York, NY 10038, United States]                 NaN
# 23  [59 Maiden Ln (William st), New York, NY 10038...                 NaN
# 24   [120 Wall St, New York, NY 10005, United States]                 NaN
# 25  [100 Wall St Fl 23, New York, NY 10005, United...                 NaN
# 26                [New York, NY 10005, United States]                 NaN
# 27   [120 Wall St, New York, NY 10005, United States]                 NaN
# 28  [110 Wall Street 11FL (Front St), New York, NY...                 NaN
# 29  [100 wall 26th, New York, NY 10005, United Sta...                 NaN
#
#                           id
# 0   4fd244dce4b03e7cee3dd4b1
# 1   4ec52dcb9911232436efc8d0
# 2   5c816dae98fbfc002bfc5e33
# 3   4b44ae92f964a52058f925e3
# 4   4b903af5f964a520b77d33e3
# 5   4f6af313e4b00b83012a586a
# 6   533b449c11d2b4ba93d9a9f8
# 7   55135e3c498e89c3a6a6f6e4
# 8   578ea005cd10fe35f4ae1e65
# 9   523c633f11d207b8ce13121c
# 10  523696fd11d2807c81e7eb89
# 11  4e6509cfb0fb188e8ecdbb6e
# 12  59d3bf6fca18ea1b0ddd8572
# 13  53da7bcd498e9839fb43320e
# 14  4ba135c2f964a52066a237e3
# 15  4f32540719836c91c7ccec82
# 16  4df4470988772e1f81570064
# 17  4bf1acbb3fa220a188931820
# 18  50b68fd9e4b0cb5f35f7bc6d
# 19  509b6744e4b00d566f350992
# 20  4d389697f8e0a093af737e67
# 21  4df659c762e1288ed30d4d8d
# 22  5d1a186d7ad194002347f53d
# 23  53df9b84498e6c335b4161a2
# 24  50dcbad78055ba17b3d55c8c
# 25  54342fce498ec8da8a6f3e40
# 26  4fedf000e4b0ac0d2ea86933
# 27  4bdeec8fffdec928491aeaa1
# 28  4c2bb11ef7acef3b4f5ced0c
# 29  4c72ad73d944224b2d4f0d29

# %% [markdown]
# ### lets see offices within the radius

# %%
dataframe_filtered.name
# Out:
# 0                                        US Post Office
# 1                     CPU Innovation Development Office
# 2                            Moinian Group Field Office
# 3                                        US Post Office
# 4                      FedEx Office Print & Ship Center
# 5                         US Post Office Collection Box
# 6          The Appellate Law Office Of Stephen Preziosi
# 7                 The Law Office of McCarthy A. Hawkins
# 8     Pace University Office of Residential Life and...
# 9                                The Office of Katmando
# 10                                    Office Best Denki
# 11                                   Apollo Docs Office
# 12                                 True Office Learning
# 13                      law office of marshall dennehey
# 14                          Bowne & Co. Printing Office
# 15                                 Ark Corporate Office
# 16                                    9fold Main Office
# 17                             NH Media downtown office
# 18                                           The Office
# 19                     FedEx Office Print & Ship Center
# 20                                   Todd Burkes Office
# 21                                   Matt's Office @717
# 22                           USPS Post Office - John St
# 23                      Office of the State Comptroller
# 24                                     Executive Office
# 25                   The Law Office Of Frank Taddeo Jr.
# 26                                   Dr. Levey's Office
# 27    CenterLink: The Community Of LGBT Centers - Ma...
# 28                         ict4me usa - new york office
# 29                              Steve & Dmitriys Office
# Name: name, dtype: object

# %% [markdown]
# ### get a map on the places on interest

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around The Subway

# add a red circle marker to represent the The Subway
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='The Subway',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the offices around The Subway as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Find popular spots around The Subway Station. This will help you select the best location depending on popularity

# %%
# Subway coordinates 
latitude = 40.7061
longitude = -74.0046

# %%
#define URL
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=XW0IGSY5NENK2FK0YRS0HV3RSULEFHPEWBPUMMYVL3U4Y0RQ&client_secret=V2XH10X5Q55G3WWZ4XAXVDMNZJZIXFRYFLYVGERKEUX5OEYD&ll=40.7061,-74.0046&v=20180604&radius=500&limit=30'

# %% [markdown]
# ### Send GET request and examine results¶

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} venues around The Subway.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 venues around The Subway.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '3fd66200f964a520daf11ee3',
#   'name': 'South Street Seaport',
#   'location': {'address': 'South St',
#    'crossStreet': 'Pier 17',
#    'lat': 40.70689585328108,
#    'lng': -74.00367135545213,
#    'distance': 118,
#    'postalCode': '10038',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['South St (Pier 17)',
#     'New York, NY 10038',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1e0941735',
#     'name': 'Harbor / Marina',
#     'pluralName': 'Harbors / Marinas',
#     'shortName': 'Harbor / Marina',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/harbor_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '59071427'}},
#  'referralId': 'e-0-3fd66200f964a520daf11ee3-0'}

# %% [markdown]
# ### Process JSON and convert it to a clean dataframe¶

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                      name                     categories  \
# 0                    South Street Seaport                Harbor / Marina
# 1             Bowne & Co. Printing Office  Paper / Office Supplies Store
# 2                    East River Esplanade               Pedestrian Plaza
# 3                               Crown Shy                     Restaurant
# 4                         McNally Jackson                      Bookstore
# 5                          SoulCycle FiDi                   Cycle Studio
# 6                                 Dig Inn            American Restaurant
# 7  Imagination Playground at Burling Slip                     Playground
# 8                   The Rooftop @ Pier 17                    Music Venue
# 9                        Hole In The Wall                 Breakfast Spot
#
#                              address               crossStreet        lat  \
# 0                           South St                   Pier 17  40.706896
# 1                   207-209 Water St  btwn Fulton & Beekman St  40.707362
# 2                           South St   From Pier 11 to Pier 17  40.704847
# 3                         70 Pine St                       NaN  40.706187
# 4                        4 Fulton St                 South St.  40.706502
# 5                      101 Maiden Ln      btwn Gold & Pearl St  40.706904
# 6                         80 Pine St               at Pearl St  40.706285
# 7  John St (at South Street Seaport)     btw Front & South Sts  40.706233
# 8                        89 South St                       NaN  40.705463
# 9                        15 Cliff St     btwn Fulton & John St  40.708280
#
#          lng  distance postalCode  cc      city state        country  \
# 0 -74.003671       118      10038  US  New York    NY  United States
# 1 -74.003504       168      10038  US  New York    NY  United States
# 2 -74.004593       139      10038  US  New York    NY  United States
# 3 -74.007490       244      10005  US  New York    NY  United States
# 4 -74.003513       102      10038  US  New York    NY  United States
# 5 -74.006717       199      10038  US  New York    NY  United States
# 6 -74.007011       204      10005  US  New York    NY  United States
# 7 -74.004215        35        NaN  US  New York    NY  United States
# 8 -74.001598       263      10038  US  New York    NY  United States
# 9 -74.005612       257      10038  US  New York    NY  United States
#
#                                     formattedAddress  \
# 0  [South St (Pier 17), New York, NY 10038, Unite...
# 1  [207-209 Water St (btwn Fulton & Beekman St), ...
# 2  [South St (From Pier 11 to Pier 17), New York,...
# 3    [70 Pine St, New York, NY 10005, United States]
# 4  [4 Fulton St (South St.), New York, NY 10038, ...
# 5  [101 Maiden Ln (btwn Gold & Pearl St), New Yor...
# 6  [80 Pine St (at Pearl St), New York, NY 10005,...
# 7  [John St (at South Street Seaport) (btw Front ...
# 8   [89 South St, New York, NY 10038, United States]
# 9  [15 Cliff St (btwn Fulton & John St), New York...
#
#                                       labeledLatLngs        neighborhood  \
# 0                                                NaN                 NaN
# 1  [{'label': 'display', 'lat': 40.70736232302747...  Financial District
# 2  [{'label': 'display', 'lat': 40.70484714530104...                 NaN
# 3  [{'label': 'display', 'lat': 40.70618693053086...                 NaN
# 4  [{'label': 'display', 'lat': 40.706502, 'lng':...                 NaN
# 5  [{'label': 'display', 'lat': 40.70690416548221...                 NaN
# 6  [{'label': 'display', 'lat': 40.7062847, 'lng'...                 NaN
# 7  [{'label': 'display', 'lat': 40.7062325343663,...                 NaN
# 8  [{'label': 'display', 'lat': 40.70546283217086...                 NaN
# 9  [{'label': 'display', 'lat': 40.70827996310331...  Financial District
#
#                          id
# 0  3fd66200f964a520daf11ee3
# 1  4ba135c2f964a52066a237e3
# 2  4e1bc07fa809bd1305bff584
# 3  5c883f65f4b525002c0bf2ca
# 4  5d5c817b011df00008ec5a40
# 5  5459292b498e72e209527504
# 6  4a7ef289f964a52058f21fe3
# 7  4c4e02acdb2c20a1be3bbc73
# 8  5b4fc2b467af3a002c9ab00f
# 9  58fdf5ec6cf01a4f54c7792b

# %% [markdown]
# ### Let's visualize these items on the map around our location¶

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around The Subway


# add The Subway as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='The Subway',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## LOCATE THE PLACES WITH THE HIGHEST FOOT TRAFFIC. THIS WILL BE THE PLACE THAT IS EASILY ACCESSIBLE AND CAN MARKET YOUR OFFICE BETTER

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e9cea71006dce001be9ff7a'},
#  'response': {'venues': []}}
